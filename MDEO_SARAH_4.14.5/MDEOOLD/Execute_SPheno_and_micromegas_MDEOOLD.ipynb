# %%
cd /home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/SPheno
# Out:
# /home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/SPheno

# %%
rm -r MDEOOLD

# %%
mkdir MDEOOLD

# %%
cd MDEOOLD
# Out:
# /home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/SPheno/MDEOOLD

# %%
cp -r /home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/SARAH/Output/MDEOOLD/EWSB/SPheno/* .

# %%
cd ..
# Out:
# /home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/SPheno

# %%
# !make Model=MDEOOLD
# Out:
# cd MDEOOLD ; make F90=gfortran version=400.00
# make[1]: Verzeichnis „/home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/SPheno/MDEOOLD“ wird betreten
# cd ../src ; make F90=gfortran
# make[2]: Verzeichnis „/home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/SPheno/src“ wird betreten
# gfortran -o SPheno -O   SPheno4.o ../lib/../lib/libSPheno.a
# mv SPheno ../bin
# make[2]: Verzeichnis „/home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/SPheno/src“ wird verlassen
# make F90=gfortran ../lib/libSPhenoMDEOOLD.a
# make[2]: Verzeichnis „/home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/SPheno/MDEOOLD“ wird betreten
# gfortran -c -g -ffree-line-length-none -J../include -I../include   Settings.f90
# ar -ruc -U ../lib/libSPhenoMDEOOLD.a Settings.o
# rm -f Settings.o
# gfortran -c -g -ffree-line-length-none -J../include -I../include   Model_Data_MDEOOLD.f90
# ar -ruc -U ../lib/libSPhenoMDEOOLD.a Model_Data_MDEOOLD.o
# rm -f Model_Data_MDEOOLD.o
# ...

# %%
cd bin
# Out:
# /home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/SPheno/bin

# %%
# !./SPhenoMDEOOLD /home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/SPHENO/MDEOOLD/Input_Files/LesHouches.in.MDEOOLD
# Out:
#  Calculating branching ratios and decay widths
#  Calculating low energy constraints
#  Calculating unitarity constraints
#  Best submatrix:            1
#  Writing output files
#  Finished!

# %%
cd /home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/micromegas
# Out:
# /home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/micromegas

# %%
# !make
# Out:
# make -C CalcHEP_src  MICROMEGAS=MICROMEGAS
# make[1]: Verzeichnis „/home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/micromegas/CalcHEP_src“ wird betreten
# ./getFlags
# numerical type Ok
# C compiler detected
# : shared liblary generation OK
# X11 OK
# Fortran compiler is detected
# gfortran OK
# FFLAGS OK
# ./sbin/setPath /home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/micromegas/CalcHEP_src
# chmod 755 mkWORKdir
# make -C c_source
# make[2]: Verzeichnis „/home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/micromegas/CalcHEP_src/c_source“ wird betreten
# make -C getmem
# make[3]: Verzeichnis „/home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/micromegas/CalcHEP_src/c_source/getmem“ wird betreten
# gcc -g -fsigned-char -std=gnu99 -fPIC -Iinclude -I../chep_crt/include   -c -o getmem.o getmem.c
# ar rv ../../lib/serv.a getmem.o
# r - getmem.o
# ranlib ../../lib/serv.a
# ...

# %%
rm -r MDEOOLD

# %%
# !./newProject MDEOOLD
# Out:
# data.par
# lib/
# lib/Makefile
# lib/pmodel.h
# lib/pmodel.fh
# lib/model.c
# main.c
# main.cpp
# Makefile
# README
# work/
# work/Makefile
# work/so_generated/
# work/lanhep/
# work/lanhep/Makefile
# work/calchep.ini
# work/models/
# work/models/vars1.mdl
# work/models/lgrng1.mdl
# work/models/func1.mdl
# work/models/prtcls1.mdl
# work/models/extlib1.mdl
# work/calchep
# work/results/
# work/tmp/

# %%
cd MDEOOLD/work/models
# Out:
# /home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/micromegas/MDEOOLD/work/models

# %%
cp -r /home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/SARAH/Output/MDEOOLD/EWSB/CHep/* .

# %%
cd ..
# Out:
# /home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/micromegas/MDEOOLD

# %%
cp -r /home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/SARAH/Output/MDEOOLD/EWSB/CHep/CalcOmega_MOv5.cpp .

# %%
cp -r /home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/SPheno/bin/SPheno.spc.MDEOOLD .

# %%
# !make main=CalcOmega_MOv5.cpp
# Out:
# make -C work
# make[1]: Verzeichnis „/home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/micromegas/MDEOOLD/work“ wird betreten
# gcc -g -fsigned-char -std=gnu99 -fPIC -I../../CalcHEP_src/include   -c -o VandP.o VandP.c
# ar rv work_aux.a VandP.o
# r - VandP.o
# gcc -g -fsigned-char -std=gnu99 -fPIC -I../../CalcHEP_src/include   -c -o path.o path.c
# ar rv work_aux.a path.o
# r - path.o
# ranlib work_aux.a
# rm -f VandP.o  path.o
# make[1]: Verzeichnis „/home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/micromegas/MDEOOLD/work“ wird verlassen
# make -C lib
# make[1]: Verzeichnis „/home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/micromegas/MDEOOLD/lib“ wird betreten
# gcc -g -fsigned-char -std=gnu99 -fPIC   -c -o model.o model.c
# ar rv aLib.a model.o
# ar: creating aLib.a
# a - model.o
# ranlib aLib.a
# rm -f model.o
# make[1]: Verzeichnis „/home/david/Downloads/Tesis/Automatic_Submodules_MDEOOLD/micromegas/MDEOOLD/lib“ wird verlassen
# make -C ../sources
# ...

# %%
# !./CalcOmega_MOv5
# Out:
# Masses of odd sector Particles:
# ~Chi     : MChi    = 176.223 || ~~Xi1    : MXi1    = 189.449 || ~~Xi2    : MXi2    = 316.450
# ~~Xi3    : MXi3    = 430.285 ||
# PROCESS: ~Chi,~Chi->AllEven,1*x{h1,h2,g,A,Z,Zp,Wm,Wp,d1,D1,d2,D2,d3,D3,u1,U1,u2,U2,u3,U3,e1,E1,e2,E2,e3,E3,nu1,nu2,nu3,nu4,nu5
# Processes of this type are absent
# PROCESS: ~Chi,~chi->AllEven,1*x{h1,h2,g,A,Z,Zp,Wm,Wp,d1,D1,d2,D2,d3,D3,u1,U1,u2,U2,u3,U3,e1,E1,e2,E2,e3,E3,nu1,nu2,nu3,nu4,nu5
# PROCESS: ~Chi,~~Xi1->AllEven,1*x{h1,h2,g,A,Z,Zp,Wm,Wp,d1,D1,d2,D2,d3,D3,u1,U1,u2,U2,u3,U3,e1,E1,e2,E2,e3,E3,nu1,nu2,nu3,nu4,nu5
# Processes of this type are absent
# PROCESS: ~Chi,~~xi1->AllEven,1*x{h1,h2,g,A,Z,Zp,Wm,Wp,d1,D1,d2,D2,d3,D3,u1,U1,u2,U2,u3,U3,e1,E1,e2,E2,e3,E3,nu1,nu2,nu3,nu4,nu5
# Processes of this type are absent
# PROCESS: ~~Xi1,~~Xi1->AllEven,1*x{h1,h2,g,A,Z,Zp,Wm,Wp,d1,D1,d2,D2,d3,D3,u1,U1,u2,U2,u3,U3,e1,E1,e2,E2,e3,E3,nu1,nu2,nu3,nu4,nu5
# Processes of this type are absent
# ...
